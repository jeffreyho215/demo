# %%
#purpose: compare W/L ratio with salary and calculate their correlations from 15 to 22

import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import numpy as np
import seaborn as sns
import scipy.stats as stats

#salary in 2022 length 5 entry short than everything else
url="https://hoopshype.com/salaries/players"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length1=salary_table.find_all("td")
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(9,3008,8)]
column1=[salary_table.find_all("td")[i].text.strip() for i in range(10,3008,8)]

#salary in 2021
url="https://hoopshype.com/salaries/players/2021-2022"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length1=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column2=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]

#salary in 2020
url="https://hoopshype.com/salaries/players/2020-2021"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column3=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]

#salary in 2019
url="https://hoopshype.com/salaries/players/2019-2020"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length3=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column4=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]

#salary in 2018
url="https://hoopshype.com/salaries/players/2018-2019"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length3=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column5=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]

#salary in 2017
url="https://hoopshype.com/salaries/players/2017-2018"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length3=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column6=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]

#salary in 2016
url="https://hoopshype.com/salaries/players/2016-2017"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length3=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column7=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]

#salary in 2015
url="https://hoopshype.com/salaries/players/2015-2016"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length3=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(5,1504,4)]
column8=[salary_table.find_all("td")[i].text.strip() for i in range(7,1504,4)]



#summing the salaries up into a dict then a df
df_dict={'player_names':player_names,
        '2022/23':column1}
df_dict1={'player_names':player_names,
        '2021/22':column2}
df_dict2={'player_names':player_names,
        '2020/21':column3}
df_dict3={'player_names':player_names,
        '2019/20':column4}
df_dict4={'player_names':player_names,
        '2018/19':column5}
df_dict5={'player_names':player_names,
        '2017/18':column6}
df_dict6={'player_names':player_names,
        '2016/17':column7}
df_dict7={'player_names':player_names,
        '2015/16':column8}
salary_df=pd.DataFrame(df_dict)
salary_df1=pd.DataFrame(df_dict1)
salary_df2=pd.DataFrame(df_dict2)
salary_df3=pd.DataFrame(df_dict3)
salary_df4=pd.DataFrame(df_dict4)
salary_df5=pd.DataFrame(df_dict5)
salary_df6=pd.DataFrame(df_dict6)
salary_df7=pd.DataFrame(df_dict7)


salary_df.replace({'\$':''}, regex = True,inplace=True)
salary_df.replace(',','', regex=True, inplace=True)

salary_df1.replace({'\$':''}, regex = True,inplace=True)
salary_df1.replace(',','', regex=True, inplace=True)

salary_df2.replace({'\$':''}, regex = True,inplace=True)
salary_df2.replace(',','', regex=True, inplace=True)

salary_df3.replace({'\$':''}, regex = True,inplace=True)
salary_df3.replace(',','', regex=True, inplace=True)

salary_df4.replace({'\$':''}, regex = True,inplace=True)
salary_df4.replace(',','', regex=True, inplace=True)

salary_df5.replace({'\$':''}, regex = True,inplace=True)
salary_df5.replace(',','', regex=True, inplace=True)

salary_df6.replace({'\$':''}, regex = True,inplace=True)
salary_df6.replace(',','', regex=True, inplace=True)

salary_df7.replace({'\$':''}, regex = True,inplace=True)
salary_df7.replace(',','', regex=True, inplace=True)

salary_df['2022/23']=salary_df['2022/23'].astype('float64')
salary_df1['2021/22']=salary_df1['2021/22'].astype('float64')
salary_df2['2020/21']=salary_df2['2020/21'].astype('float64')
salary_df3['2019/20']=salary_df3['2019/20'].astype('float64')
salary_df4['2018/19']=salary_df4['2018/19'].astype('float64')
salary_df5['2017/18']=salary_df5['2017/18'].astype('float64')
salary_df6['2016/17']=salary_df6['2016/17'].astype('float64')
salary_df7['2015/16']=salary_df7['2015/16'].astype('float64')



#scrape from wiki team name and corresponding team abbreviation
even_no=[]
odd_no=[]
for i in range(0,61,2):
    even_no.append(i) 
    
for i in range(1,63,2):
    odd_no.append(i) 

url="https://en.wikipedia.org/wiki/Wikipedia:WikiProject_National_Basketball_Association/National_Basketball_Association_team_abbreviations"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
a=salary_table.find_all("td")
Abbreviation=[salary_table.find_all("td")[i].text.strip() for i in even_no]
Abbreviation.append('BRK')
Franchise=[salary_table.find_all("td")[i].text.strip() for i in odd_no]
Franchise.append('Brooklyn Nets')
abbr_dict={'Abbreviation':Abbreviation,
          'Franchise':Franchise}
abbr_df=pd.DataFrame(abbr_dict)
abbr_df=abbr_df.drop(0,axis=0)
abbr_df=abbr_df.sort_values('Abbreviation',ascending=True)
abbr_df=abbr_df.reset_index()
abbr_df=abbr_df.drop('index',axis=1)


#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2022
salary_df=salary_df.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df=salary_df[['player_names','2022/23','Franchise']]

salary_df=salary_df[~salary_df['Franchise'].isna()]
salary_df=salary_df.reset_index()
salary_df=salary_df.drop('index',axis=1)
salary_df=salary_df.drop('player_names',axis=1)
salary_df=salary_df.groupby(by=['Franchise']).sum()

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2021
salary_df1=salary_df1.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df1=salary_df1[['player_names','2021/22','Franchise']]
salary_df1=salary_df1[~salary_df1['Franchise'].isna()]
salary_df1=salary_df1.reset_index()
salary_df1=salary_df1.drop('index',axis=1)
salary_df1=salary_df1.drop('player_names',axis=1)
salary_df1=salary_df1.groupby(by=['Franchise']).sum()

new=salary_df.merge(salary_df1,how='outer',left_on='Franchise',right_on='Franchise')

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2020
salary_df2=salary_df2.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df2=salary_df2[['player_names','2020/21','Franchise']]
salary_df2=salary_df2[~salary_df2['Franchise'].isna()]
salary_df2=salary_df2.reset_index()
salary_df2=salary_df2.drop('index',axis=1)
salary_df2=salary_df2.drop('player_names',axis=1)
salary_df2=salary_df2.groupby(by=['Franchise']).sum()

new1=new.merge(salary_df2,how='outer',left_on='Franchise',right_on='Franchise')

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2019
salary_df3=salary_df3.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df3=salary_df3[['player_names','2019/20','Franchise']]
salary_df3=salary_df3[~salary_df3['Franchise'].isna()]
salary_df3=salary_df3.reset_index()
salary_df3=salary_df3.drop('index',axis=1)
salary_df3=salary_df3.drop('player_names',axis=1)
salary_df3=salary_df3.groupby(by=['Franchise']).sum()

new2=new1.merge(salary_df3,how='outer',left_on='Franchise',right_on='Franchise')
#new2.reset_index(inplace=True)

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2018
salary_df4=salary_df4.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df4=salary_df4[['player_names','2018/19','Franchise']]
salary_df4=salary_df4[~salary_df4['Franchise'].isna()]
salary_df4=salary_df4.reset_index()
salary_df4=salary_df4.drop('index',axis=1)
salary_df4=salary_df4.drop('player_names',axis=1)
salary_df4=salary_df4.groupby(by=['Franchise']).sum()

new3=new2.merge(salary_df4,how='outer',left_on='Franchise',right_on='Franchise')
#new3.reset_index(inplace=True)

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2017
salary_df5=salary_df5.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df5=salary_df5[['player_names','2017/18','Franchise']]
salary_df5=salary_df5[~salary_df5['Franchise'].isna()]
salary_df5=salary_df5.reset_index()
salary_df5=salary_df5.drop('index',axis=1)
salary_df5=salary_df5.drop('player_names',axis=1)
salary_df5=salary_df5.groupby(by=['Franchise']).sum()

new4=new3.merge(salary_df5,how='outer',left_on='Franchise',right_on='Franchise')
#new4.reset_index(inplace=True)

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2016
salary_df6=salary_df6.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df6=salary_df6[['player_names','2016/17','Franchise']]
salary_df6=salary_df6[~salary_df6['Franchise'].isna()]
salary_df6=salary_df6.reset_index()
salary_df6=salary_df6.drop('index',axis=1)
salary_df6=salary_df6.drop('player_names',axis=1)
salary_df6=salary_df6.groupby(by=['Franchise']).sum()

new5=new4.merge(salary_df6,how='outer',left_on='Franchise',right_on='Franchise')
#new5.reset_index(inplace=True)

#mapping the teams players belong to

stats_df=pd.read_csv(r"/Users/jeffreyho/Downloads/sportsref_download 20-21.csv")
stats_df=stats_df[['Player','Tm']]
for index, row in stats_df.iterrows():
    if row['Tm']=='TOT':
        stats_df.drop(index, inplace=True)
stats_df=stats_df.merge(abbr_df,how='left',left_on='Tm',right_on='Abbreviation')
stats_df=stats_df[['Player','Franchise']]

#merging the salary df with the team df 2015
salary_df7=salary_df7.merge(stats_df,how='left',left_on='player_names',right_on='Player')
salary_df7=salary_df7[['player_names','2015/16','Franchise']]
salary_df7=salary_df7[~salary_df7['Franchise'].isna()]
salary_df7=salary_df7.reset_index()
salary_df7=salary_df7.drop('index',axis=1)
salary_df7=salary_df7.drop('player_names',axis=1)
salary_df7=salary_df7.groupby(by=['Franchise']).sum()

new6=new5.merge(salary_df7,how='outer',left_on='Franchise',right_on='Franchise')
new6.reset_index(inplace=True)


# Taking only the place names in new7['Franchise']
l=[]
for i in new6['Franchise']:
    j=i.split(" ")
    j=j[0]
    l.append(j)
new6['Franchise']=l


#scrape for WL ratio
url="http://www.espn.com/nba/stats/rpi"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2023=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2023=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2023=[float(i) for i in win2023]
dict2023={'Franchise':name2023,'Win% 23':win2023}
df2023=pd.DataFrame(dict2023)

url="http://www.espn.com/nba/stats/rpi/_/year/2022"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2022=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2022=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2022=[float(i) for i in win2022]
dict2022={'Franchise':name2022,'Win% 22':win2022}
df2022=pd.DataFrame(dict2022)

url="http://www.espn.com/nba/stats/rpi/_/year/2021"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2021=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2021=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2021=[float(i) for i in win2021]
dict2021={'Franchise':name2021,'Win% 21':win2021}
df2021=pd.DataFrame(dict2021)

url="http://www.espn.com/nba/stats/rpi/_/year/2020"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2020=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2020=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2020=[float(i) for i in win2020]
dict2020={'Franchise':name2020,'Win% 20':win2020}
df2020=pd.DataFrame(dict2020)

url="http://www.espn.com/nba/stats/rpi/_/year/2019"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2019=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2019=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2019=[float(i) for i in win2019]
dict2019={'Franchise':name2019,'Win% 19':win2019}
df2019=pd.DataFrame(dict2019)

url="http://www.espn.com/nba/stats/rpi/_/year/2018"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2018=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2018=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2018=[float(i) for i in win2018]
dict2018={'Franchise':name2018,'Win% 18':win2018}
df2018=pd.DataFrame(dict2018)

url="http://www.espn.com/nba/stats/rpi/_/year/2017"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2017=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2017=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2017=[float(i) for i in win2017]
dict2017={'Franchise':name2017,'Win% 17':win2017}
df2017=pd.DataFrame(dict2017)

url="http://www.espn.com/nba/stats/rpi/_/year/2016"
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
salary_table = soup.find('table')
length2=salary_table.find_all("td")
name2016=[salary_table.find_all("td")[i].text.strip() for i in range(14,374,12)]
win2016=[salary_table.find_all("td")[i].text.strip() for i in range(18,374,12)]
win2016=[float(i) for i in win2016]
dict2016={'Franchise':name2016,'Win% 16':win2016}
df2016=pd.DataFrame(dict2016)



dfyear=df2016.merge(df2017,how='inner',on='Franchise')
dfyear1=dfyear.merge(df2018,how='inner',on='Franchise')
dfyear2=dfyear1.merge(df2019,how='inner',on='Franchise')
dfyear3=dfyear2.merge(df2020,how='inner',on='Franchise')
dfyear4=dfyear3.merge(df2021,how='inner',on='Franchise')
dfyear5=dfyear4.merge(df2022,how='inner',on='Franchise')
dfyear6=dfyear5.merge(df2023,how='inner',on='Franchise')

#merge with new2
new6=new6.merge(dfyear6,how='inner',on='Franchise')
new6=new6[['Franchise','2022/23','2021/22','2020/21','2019/20','2018/19','2017/18','2016/17','2015/16',
           'Win% 23','Win% 22','Win% 21','Win% 20','Win% 19','Win% 18','Win% 17','Win% 16']]
new6=new6.set_index('Franchise')

corr,pval=stats.pearsonr(new6['2022/23'],new6['Win% 23'])
corr1,pval1=stats.pearsonr(new6['2021/22'],new6['Win% 22'])
corr2,pval2=stats.pearsonr(new6['2020/21'],new6['Win% 21'])
corr3,pval3=stats.pearsonr(new6['2019/20'],new6['Win% 20'])
corr4,pval4=stats.pearsonr(new6['2018/19'],new6['Win% 19'])
corr5,pval5=stats.pearsonr(new6['2017/18'],new6['Win% 18'])
corr6,pval6=stats.pearsonr(new6['2016/17'],new6['Win% 17'])
corr7,pval7=stats.pearsonr(new6['2015/16'],new6['Win% 16'])


corr_list=[corr,corr1,corr2,corr3,corr4,corr5,corr6,corr7]
years=['2015','2016','2017','2018','2019','2020','2021','2022']

cor=[]
for i in corr_list:
    i=np.around(i,3)
    cor.append(i)
    


plt.plot(years,cor,'r--x')
plt.text(-0.38,0.08,cor[0])
plt.text(0.5,-0.05,cor[1])
plt.text(1.55,0.22,cor[2])
plt.text(2.78,0.20,cor[3])
plt.text(3.7,0.21,cor[4])
plt.text(5,0.185,cor[5])
plt.text(5.8,-0.3,cor[6])
plt.text(6.7,-0.4,cor[7])

plt.title("Correlation between Team Salary and Win Percentage")
plt.show()
